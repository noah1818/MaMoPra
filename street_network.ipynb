# %%
import osmnx as ox
import networkx as nx
'''
Built on top of NetworkX and GeoPandas, and interacts with OpenStreetMap APIs, to:

- Download and model street networks or other infrastructure anywhere in the world with a single line of code
- Download geospatial features (e.g., political boundaries, building footprints, grocery stores, transit stops) as a GeoDataFrame
- Query by city name, polygon, bounding box, or point/address + distance
- Model driving, walking, biking, and other travel modes
- Attach node elevations from a local raster file or web service and calculate edge grades
- Impute missing speeds and calculate graph edge travel times
- Simplify and correct the networks topology to clean-up nodes and consolidate complex intersections
- Fast map-matching of points, routes, or trajectories to nearest graph edges or nodes
- Save/load network to/from disk as GraphML, GeoPackage, or OSM XML file
- Conduct topological and spatial analyses to automatically calculate dozens of indicators
- Calculate and visualize street bearings and orientations
- Calculate and visualize shortest-path routes that minimize distance, travel time, elevation, etc
- Explore street networks and geospatial features as a static map or interactive web map
- Visualize travel distance and travel time with isoline and isochrone maps
- Plot figure-ground diagrams of street networks and building footprints

'''
# Out:
# '\nBuilt on top of NetworkX and GeoPandas, and interacts with OpenStreetMap APIs, to:\n\n- Download and model street networks or other infrastructure anywhere in the world with a single line of code\n- Download geospatial features (e.g., political boundaries, building footprints, grocery stores, transit stops) as a GeoDataFrame\n- Query by city name, polygon, bounding box, or point/address + distance\n- Model driving, walking, biking, and other travel modes\n- Attach node elevations from a local raster file or web service and calculate edge grades\n- Impute missing speeds and calculate graph edge travel times\n- Simplify and correct the networks topology to clean-up nodes and consolidate complex intersections\n- Fast map-matching of points, routes, or trajectories to nearest graph edges or nodes\n- Save/load network to/from disk as GraphML, GeoPackage, or OSM XML file\n- Conduct topological and spatial analyses to automatically calculate dozens of indicators\n- Calculate and visualize street bearings and orientations\n- Calculate and visualize shortest-path routes that minimize distance, travel time, elevation, etc\n- Explore street networks and geospatial features as a static map or interactive web map\n- Visualize travel distance and travel time with isoline and isochrone maps\n- Plot figure-ground diagrams of street networks and building footprints\n\n'

# %%
# load in the plot
G = ox.graph_from_place("Piedmont, California, USA", network_type="drive")

# %%
G.edges, G.nodes
# Out:
# (OutMultiEdgeView([(53017091, 53064327, 0), (53017091, 53075599, 0), (53018397, 53018399, 0), (53018397, 53018411, 0), (53018397, 53097980, 0), (53018399, 53018402, 0), (53018399, 53018397, 0), (53018399, 53078914, 0), (53018402, 53018399, 0), (53018402, 53018404, 0), (53018402, 53078914, 0), (53018404, 53064328, 0), (53018404, 53018402, 0), (53018404, 53114726, 0), (53018410, 53018411, 0), (53018410, 53057697, 0), (53018410, 53062956, 0), (53018411, 53018410, 0), (53018411, 53145241, 0), (53018411, 53018397, 0), (53021742, 683050219, 0), (53021742, 53021743, 0), (53021742, 53022623, 0), (53021743, 53021743, 0), (53021743, 53021743, 1), (53021743, 53021742, 0), (53021750, 683050221, 0), (53021750, 53021742, 0), (53021750, 53085380, 0), (53022623, 317364095, 0), (53022623, 53022625, 0), (53022623, 53021742, 0), (53022625, 53022623, 0), (53023513, 683050219, 0), (53023513, 53085382, 0), (53023513, 53122757, 0), (53025057, 2834814897, 0), (53025057, 53119166, 0), (53025057, 53082621, 0), (53025060, 2834814897, 0), (53025060, 53082627, 0), (53025060, 53073689, 0), (53025220, 53025222, 0), (53025220, 53102808, 0), (53025220, 53093365, 0), (53025222, 53025220, 0), (53027454, 53085377, 0), (53027454, 305541020, 0), (53027454, 53085380, 0), (53027455, 53040495, 0), (53027455, 53027457, 0), (53027455, 305541020, 0), (53027457, 2391023394, 0), (53027457, 53027455, 0), (53027459, 53027461, 0), (53027459, 2391023394, 0), (53027459, 53074380, 0), (53027461, 53027459, 0), (53027461, 53046249, 0), (53027461, 53027463, 0), (53027463, 53152062, 0), (53027463, 53027461, 0), (53027463, 53046250, 0), (53028190, 53028192, 0), (53028192, 53028190, 0), (53028192, 10879933448, 0), (53033660, 432431093, 0), (53033660, 53040495, 0), (53033660, 683050204, 0), (53033660, 53073691, 0), (53035698, 703006798, 0), (53035699, 2890584258, 0), (53035699, 245523440, 0), (53036557, 53090322, 0), (53036557, 53095909, 0), (53036558, 10879933448, 0), (53036558, 53095909, 0), (53036558, 317339074, 0), (53036558, 60755551, 0), (53037306, 683050115, 0), (53037306, 53037307, 0), (53037306, 53093372, 0), (53037307, 53037306, 0), (53037307, 53059175, 0), (53037307, 53059173, 0), (53040495, 53027455, 0), (53040495, 53033660, 0), (53040495, 53085375, 0), (53040794, 53097976, 0), (53041432, 245505820, 0), (53041432, 53125974, 0), (53041432, 245505298, 0), (53041437, 245505820, 0), (53041437, 53118299, 0), (53041437, 53145205, 0), (53041440, 53114734, 0), (53041440, 53115407, 0), (53041440, 53041442, 0), (53041442, 53042706, 0), (53041442, 53093356, 0), (53041442, 53041443, 0), (53041442, 53041440, 0), (53041443, 53041445, 0), (53041443, 53119164, 0), (53041443, 53042707, 0), (53041443, 53041442, 0), (53041445, 53041443, 0), (53041445, 53082619, 0), (53041445, 2833994093, 0), (53041668, 9124733144, 0), (53041668, 53041670, 0), (53041668, 53060462, 0), (53041670, 53041668, 0), (53042706, 53042707, 0), (53042706, 53089336, 0), (53042706, 53041442, 0), (53042707, 53042706, 0), (53042707, 53119166, 0), (53042707, 53041443, 0), (53044573, 53044575, 0), (53044575, 53044573, 0), (53044575, 53073816, 0), (53044575, 53073822, 0), (53044661, 53075311, 0), (53044661, 9656853494, 0), (53044661, 9656853491, 0), (53044664, 53144226, 0), (53044664, 53118296, 0), (53044664, 9656853494, 0), (53046249, 53046250, 0), (53046249, 53127240, 0), (53046249, 53027461, 0), (53046250, 53046249, 0), (53046250, 53046251, 0), (53046250, 53027463, 0), (53046251, 53046252, 0), (53046251, 53125997, 0), (53046251, 53046250, 0), (53046252, 53046253, 0), (53046252, 53101282, 0), (53046252, 53046251, 0), (53046253, 53046254, 0), (53046253, 53046252, 0), (53046253, 53050874, 0), (53046254, 53046255, 0), (53046254, 53046253, 0), (53046254, 53133008, 0), (53046255, 53046254, 0), (53046255, 53092207, 0), (53046255, 53092203, 0), (53050874, 53092207, 0), (53050874, 53050875, 0), (53050874, 53046253, 0), (53050875, 53050874, 0), (53050875, 53092210, 0), (53050875, 53101285, 0), (53057697, 10747500178, 0), (53057697, 5 ...
#  NodeView((53017091, 53018397, 53018399, 53018402, 53018404, 53018410, 53018411, 53021742, 53021743, 53021750, 53022623, 53022625, 53023513, 53025057, 53025060, 53025220, 53025222, 53027454, 53027455, 53027457, 53027459, 53027461, 53027463, 53028190, 53028192, 53033660, 53035698, 53035699, 53036557, 53036558, 53037306, 53037307, 53040495, 53040794, 53041432, 53041437, 53041440, 53041442, 53041443, 53041445, 53041668, 53041670, 53042706, 53042707, 53044573, 53044575, 53044661, 53044664, 53046249, 53046250, 53046251, 53046252, 53046253, 53046254, 53046255, 53050874, 53050875, 53057697, 53059166, 53059173, 53059175, 53059186, 53059187, 53059189, 53059885, 53060462, 53060465, 53060466, 53060467, 53060468, 53060469, 53060471, 53060473, 53062956, 53062958, 53064300, 53064302, 53064305, 53064327, 53064328, 53064330, 53064331, 53065783, 53065785, 53066716, 53066717, 53068822, 53068826, 53068829, 53073689, 53073691, 53073816, 53073822, 53073843, 53074376, 53074377, 53074380, 53075311, 53075599, 53075602, 53075606, 53076244, 53076245, 53076246, 53076247, 53076250, 53076382, 53076384, 53076391, 53076392, 53076395, 53076399, 53077316, 53078467, 53078468, 53078469, 53078473, 53078914, 53079888, 53080198, 53081989, 53081990, 53082619, 53082621, 53082625, 53082627, 53082632, 53082634, 53082640, 53082643, 53082644, 53082645, 53085009, 53085375, 53085377, 53085380, 53085382, 53085385, 53085387, 53085388, 53085389, 53086074, 53088880, 53088882, 53089336, 53090322, 53090323, 53090940, 53091598, 53092199, 53092201, 53092203, 53092207, 53092210, 53092214, 53092218, 53092220, 53092226, 53093356, 53093359, 53093360, 53093362, 53093365, 53093372, 53095909, 53097380, 53097585, 53097586, 53097976, 53097980, 53099375, 53100222, 53100223, 53100813, 53101282, 53101285, 53102808, 53107191, 53107192, 53108990, 53108992, 53111728, 53111730, 53112467, 53112473, 53112476, 53113943, 53113946, 53113947, 53114726, 53114727, 53114730, 53114732, 53114734, 53115407, 53116276, 53116302, 53116304, 53116661, 53116662, 53116664, 53116672, 53117097, 53117098, 53117160, 53117166, 53118296, 53118299, 53118366, 53118368, 53118372, 53118374, 53118376, 53118380, 53119042, 53119160, 53119162, 53119164, 53119166, 53119168, 53122757, 53123865, 53124803, 53124805, 53124807, 53124973, 53125573, 53125575, 53125725, 53125973, 53125974, 53125997, 53125999, 53126000, 53126347, 53126350, 53127240, 53128727, 53128729, 53128733, 53133008, 53134176, 53134227, 53137611, 53140452, 53140454, 53142555, 53142908, 53143484, 53143485, 53144226, 53144229, 53145205, 53145241, 53146451, 53148306, 53149343, 53149671, 53149673, 53152062, 53152069, 53152083, 53152921, 53155115, 53156140, 53156142, 53156408, 53156410, 53156415, 53156417, 53157145, 60755551, 245118228, 245118288, 245118387, 245118772, 245384115, 245386862, 245387557, 245387832, 245505298, 245505820, 245523440, 246744892, 247141128, 247141145, 256338428, 256338808, 256338809, 256338812, 256338813, 256339663, 256340150, 256543149, 260706808, 260707354, 260707479, 260707482, 305541020, 305541919, 311882161, 311884105, 317339074, 317363251, 317364095, 370467066, 432431093, 442842707, 682821166, 682931951, 683050066, 683050115, 683050120, 683050204, 683050219, 683050221, 683790465, 683790519, 683790735, 686194326, 686202982, 686203266, 687156433, 703006798, 956500319, 2286923088, 2286923094, 2391023380, 2391023394, 2391023402, 2518218246, 2833994093, 2834031502, 2834093713, 2834814897, 2834816916, 2890584258, 3905291938, 4606504193, 4671607162, 8573260363, 9124733144, 9124766429, 9231102999, 9656853491, 9656853494, 10232094660, 10677487586, 10684132265, 10747500178, 10879933448, 11036463561)))

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
# convert your MultiDiGraph to an undirected MultiGraph
#M = ox.convert.to_undirected(G)

# convert your MultiDiGraph to a DiGraph without parallel edges
D = ox.convert.to_digraph(G)

# not necessary in our case

# %%
# impute speed on all edges missing data
G = ox.add_edge_speeds(G)

# calculate travel time (seconds) for all edges
G = ox.add_edge_travel_times(G)

# %%
# see mean speed/time values by road type
edges = ox.graph_to_gdfs(G, nodes=False)
edges["highway"] = edges["highway"].astype(str)
edges.groupby("highway")[["length", "speed_kph", "travel_time"]].mean().round(1)
# Out:
#                length  speed_kph  travel_time
# highway
# residential     123.1       25.1         17.7
# secondary       112.0       44.3          9.2
# tertiary        103.5       40.2          9.3
# tertiary_link    56.3       36.5          5.6
# unclassified     28.7       36.5          2.8

# %%
# what sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# /var/folders/02/895d_ly16w54v11n_x2ttx2h0000gn/T/ipykernel_57547/4260142167.py:4: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   graph_area_m = nodes_proj.unary_union.convex_hull.area
# 4199465.640327393

# %%
# show some basic stats about the network
ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# {'n': 352,
#  'm': 944,
#  'k_avg': 5.363636363636363,
#  'edge_length_total': 112049.277,
#  'edge_length_avg': 118.69626800847458,
#  'streets_per_node_avg': np.float64(2.9488636363636362),
#  'streets_per_node_counts': {0: 0, 1: 34, 2: 0, 3: 270, 4: 46, 5: 2},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.09659090909090909,
#   2: 0.0,
#   3: 0.7670454545454546,
#   4: 0.13068181818181818,
#   5: 0.005681818181818182},
#  'intersection_count': np.int64(318),
#  'street_length_total': 58086.481,
#  'street_segment_count': 495,
#  'street_length_avg': 117.34642626262627,
#  'circuity_avg': np.float64(1.1112710818481102),
#  'self_loop_proportion': 0.006060606060606061,
#  'clean_intersection_count': 267,
#  'node_density_km': 83.82018812578208,
#  'intersection_density_km': np.float64(75.72391995454177),
#  'edge_density_km': 26681.7939701644,
#  'street_density_km': 13831.874332342803,
#  'clean_intersection_density_km': 63.5795176976813}

# %%
# convert graph to line graph so edges become nodes and vice versa
edge_centrality = nx.closeness_centrality(nx.line_graph(G))
nx.set_edge_attributes(G, edge_centrality, "edge_centrality")

# %%
# color edges in original graph with closeness centralities from line graph
ec = ox.plot.get_edge_colors_by_attr(G, "edge_centrality", cmap="inferno")
fig, ax = ox.plot_graph(G, edge_color=ec, edge_linewidth=2, node_size=0)

# %%
# impute missing edge speeds and calculate edge travel times with the speed module
G = ox.routing.add_edge_speeds(G)
G = ox.routing.add_edge_travel_times(G)

# %%
# print the travel speed for all edges and nodes

nodes = list(G.nodes(data=True))
edges = list(G.edges(data=True))
for u, v, data in G.edges(data=True):
    travel_speed = data.get('speed_kph', 'Unknown')  # Replace 'speed_kph' with the actual key if different
    print(f"Edge from {u} to {v} has travel speed: {travel_speed} km/h")
# Out:
# Edge from 53017091 to 53064327 has travel speed: 25.1 km/h
# Edge from 53017091 to 53075599 has travel speed: 25.1 km/h
# Edge from 53018397 to 53018399 has travel speed: 25.1 km/h
# Edge from 53018397 to 53018411 has travel speed: 40.2 km/h
# Edge from 53018397 to 53097980 has travel speed: 40.2 km/h
# Edge from 53018399 to 53018402 has travel speed: 25.1 km/h
# Edge from 53018399 to 53018397 has travel speed: 25.1 km/h
# Edge from 53018399 to 53078914 has travel speed: 25.1 km/h
# Edge from 53018402 to 53018399 has travel speed: 25.1 km/h
# Edge from 53018402 to 53018404 has travel speed: 25.1 km/h
# Edge from 53018402 to 53078914 has travel speed: 25.1 km/h
# Edge from 53018404 to 53064328 has travel speed: 25.1 km/h
# Edge from 53018404 to 53018402 has travel speed: 25.1 km/h
# Edge from 53018404 to 53114726 has travel speed: 25.1 km/h
# Edge from 53018410 to 53018411 has travel speed: 25.1 km/h
# Edge from 53018410 to 53057697 has travel speed: 25.1 km/h
# Edge from 53018410 to 53062956 has travel speed: 25.1 km/h
# Edge from 53018411 to 53018410 has travel speed: 25.1 km/h
# Edge from 53018411 to 53145241 has travel speed: 40.2 km/h
# Edge from 53018411 to 53018397 has travel speed: 40.2 km/h
# Edge from 53021742 to 683050219 has travel speed: 25.1 km/h
# Edge from 53021742 to 53021743 has travel speed: 25.1 km/h
# Edge from 53021742 to 53022623 has travel speed: 25.1 km/h
# Edge from 53021743 to 53021743 has travel speed: 25.1 km/h
# Edge from 53021743 to 53021743 has travel speed: 25.1 km/h
# Edge from 53021743 to 53021742 has travel speed: 25.1 km/h
# Edge from 53021750 to 683050221 has travel speed: 40.2 km/h
# Edge from 53021750 to 53021742 has travel speed: 25.1 km/h
# Edge from 53021750 to 53085380 has travel speed: 40.2 km/h
# Edge from 53022623 to 317364095 has travel speed: 25.1 km/h
# Edge from 53022623 to 53022625 has travel speed: 25.1 km/h
# Edge from 53022623 to 53021742 has travel speed: 25.1 km/h
# Edge from 53022625 to 53022623 has travel speed: 25.1 km/h
# Edge from 53023513 to 683050219 has travel speed: 25.1 km/h
# Edge from 53023513 to 53085382 has travel speed: 40.2 km/h
# Edge from 53023513 to 53122757 has travel speed: 40.2 km/h
# Edge from 53025057 to 2834814897 has travel speed: 25.1 km/h
# Edge from 53025057 to 53119166 has travel speed: 25.1 km/h
# Edge from 53025057 to 53082621 has travel speed: 25.1 km/h
# Edge from 53025060 to 2834814897 has travel speed: 25.1 km/h
# Edge from 53025060 to 53082627 has travel speed: 40.2 km/h
# Edge from 53025060 to 53073689 has travel speed: 40.2 km/h
# Edge from 53025220 to 53025222 has travel speed: 25.1 km/h
# Edge from 53025220 to 53102808 has travel speed: 25.1 km/h
# Edge from 53025220 to 53093365 has travel speed: 25.1 km/h
# Edge from 53025222 to 53025220 has travel speed: 25.1 km/h
# Edge from 53027454 to 53085377 has travel speed: 40.2 km/h
# Edge from 53027454 to 305541020 has travel speed: 25.1 km/h
# Edge from 53027454 to 53085380 has travel speed: 40.2 km/h
# Edge from 53027455 to 53040495 has travel speed: 25.1 km/h
# Edge from 53027455 to 53027457 has travel speed: 25.1 km/h
# Edge from 53027455 to 305541020 has travel speed: 25.1 km/h
# Edge from 53027457 to 2391023394 has travel speed: 25.1 km/h
# Edge from 53027457 to 53027455 has travel speed: 25.1 km/h
# Edge from 53027459 to 53027461 has travel speed: 25.1 km/h
# Edge from 53027459 to 2391023394 has travel speed: 25.1 km/h
# Edge from 53027459 to 53074380 has travel speed: 25.1 km/h
# Edge from 53027461 to 53027459 has travel speed: 25.1 km/h
# Edge from 53027461 to 53046249 has travel speed: 25.1 km/h
# Edge from 53027461 to 53027463 has travel speed: 25.1 km/h
# Edge from 53027463 to 53152062 has travel speed: 40.2 km/h
# Edge from 53027463 to 53027461 has travel speed: 25.1 km/h
# Edge from 53027463 to 53046250 has travel speed: 40.2 km/h
# Edge from 53028190 to 53028192 has travel speed: 25.1 km/h
# Edge from 53028192 to 53028190 has travel speed: 25.1 km/h
# Edge from 53028192 to 10879933448 has travel speed: 25.1 km/h
# Edge from 53033660 to 432431093 has travel speed: 25.1 km/h
# Edge from 53033660 to 53040495 has travel speed: 40.2 km/h
# Edge from 53033660 to 683050204 has travel speed: 25.1 km/h
# Edge from 53033660 to 53073691 has travel speed: 40.2 km/h
# Edge from 53035698 to 703006798 has travel speed: 40.2 km/h
# Edge from 53035699 to 2890584258 has travel speed: 24.1 km/h
# Edge from 53035699 to 245523440 has travel speed: 56.3 km/h
# Edge from 53036557 to 53090322 has travel speed: 25.1 km/h
# Edge from 53036557 to 53095909 has travel speed: 25.1 km/h
# Edge from 53036558 to 10879933448 has travel speed: 40.2 km/h
# Edge from 53036558 to 53095909 has travel speed: 40.2 km/h
# Edge from 53036558 to 317339074 has travel speed: 40.2 km/h
# Edge from 53036558 to 60755551 has travel speed: 24.1 km/h
# Edge from 53037306 to 683050115 has travel speed: 25.1 km/h
# Edge from 53037306 to 53037307 has travel speed: 25.1 km/h
# Edge from 53037306 to 53093372 has travel speed: 25.1 km/h
# Edge from 53037307 to 53037306 has travel speed: 25.1 km/h
# Edge from 53037307 to 53059175 has travel speed: 25.1 km/h
# Edge from 53037307 to 53059173 has travel speed: 25.1 km/h
# Edge from 53040495 to 53027455 has travel speed: 25.1 km/h
# Edge from 53040495 to 53033660 has travel speed: 40.2 km/h
# Edge from 53040495 to 53085375 has travel speed: 40.2 km/h
# Edge from 53040794 to 53097976 has travel speed: 25.1 km/h
# Edge from 53041432 to 245505820 has travel speed: 25.1 km/h
# Edge from 53041432 to 53125974 has travel speed: 40.2 km/h
# Edge from 53041432 to 245505298 has travel speed: 40.2 km/h
# Edge from 53041437 to 245505820 has travel speed: 25.1 km/h
# Edge from 53041437 to 53118299 has travel speed: 40.2 km/h
# Edge from 53041437 to 53145205 has travel speed: 40.2 km/h
# Edge from 53041440 to 53114734 has travel speed: 25.1 km/h
# Edge from 53041440 to 53115407 has travel speed: 25.1 km/h
# Edge from 53041440 to 53041442 has travel speed: 25.1 km/h
# Edge from 53041442 to 53042706 has travel speed: 25.1 km/h
# Edge from 53041442 to 53093356 has travel speed: 25.1 km/h
# Edge from 53041442 to 53041443 has travel speed: 25.1 km/h
# Edge from 53041442 to 53041440 has travel speed: 25.1 km/h
# Edge from 53041443 to 53041445 has travel speed: 25.1 km/h
# Edge from 53041443 to 53119164 has travel speed: 40.2 km/h
# Edge from 53041443 to 53042707 has travel speed: 40.2 km/h
# Edge from 53041443 to 53041442 has travel speed: 25.1 km/h
# Edge from 53041445 to 53041443 has travel speed: 25.1 km/h
# Edge from 53041445 to 53082619 has travel speed: 25.1 km/h
# Edge from 53041445 to 2833994093 has travel speed: 25.1 km/h
# Edge from 53041668 to 9124733144 has travel speed: 25.1 km/h
# Edge from 53041668 to 53041670 has travel speed: 25.1 km/h
# Edge from 53041668 to 53060462 has travel speed: 25.1 km/h
# Edge from 53041670 to 53041668 has travel speed: 25.1 km/h
# Edge from 53042706 to 53042707 has travel speed: 25.1 km/h
# Edge from 53042706 to 53089336 has travel speed: 25.1 km/h
# Edge from 53042706 to 53041442 has travel speed: 25.1 km/h
# Edge from 53042707 to 53042706 has travel speed: 25.1 km/h
# Edge from 53042707 to 53119166 has travel speed: 40.2 km/h
# Edge from 53042707 to 53041443 has travel speed: 40.2 km/h
# Edge from 53044573 to 53044575 has travel speed: 25.1 km/h
# Edge from 53044575 to 53044573 has travel speed: 25.1 km/h
# Edge from 53044575 to 53073816 has travel speed: 25.1 km/h
# Edge from 53044575 to 53073822 has travel speed: 25.1 km/h
# Edge from 53044661 to 53075311 has travel speed: 24.1 km/h
# Edge from 53044661 to 9656853494 has travel speed: 25.1 km/h
# Edge from 53044661 to 9656853491 has travel speed: 24.1 km/h
# Edge from 53044664 to 53144226 has travel speed: 25.1 km/h
# Edge from 53044664 to 53118296 has travel speed: 25.1 km/h
# Edge from 53044664 to 9656853494 has travel speed: 25.1 km/h
# Edge from 53046249 to 53046250 has travel speed: 25.1 km/h
# Edge from 53046249 to 53127240 has travel speed: 25.1 km/h
# Edge from 53046249 to 53027461 has travel speed: 25.1 km/h
# Edge from 53046250 to 53046249 has travel speed: 25.1 km/h
# Edge from 53046250 to 53046251 has travel speed: 40.2 km/h
# Edge from 53046250 to 53027463 has travel speed: 40.2 km/h
# Edge from 53046251 to 53046252 has travel speed: 40.2 km/h
# Edge from 53046251 to 53125997 has travel speed: 40.2 km/h
# Edge from 53046251 to 53046250 has travel speed: 40.2 km/h
# Edge from 53046252 to 53046253 has travel speed: 40.2 km/h
# Edge from 53046252 to 53101282 has travel speed: 25.1 km/h
# Edge from 53046252 to 53046251 has travel speed: 40.2 km/h
# Edge from 53046253 to 53046254 has travel speed: 40.2 km/h
# Edge from 53046253 to 53046252 has travel speed: 40.2 km/h
# Edge from 53046253 to 53050874 has travel speed: 25.1 km/h
# Edge from 53046254 to 53046255 has travel speed: 40.2 km/h
# Edge from 53046254 to 53046253 has travel speed: 40.2 km/h
# Edge from 53046254 to 53133008 has travel speed: 25.1 km/h
# Edge from 53046255 to 53046254 has travel speed: 40.2 km/h
# Edge from 53046255 to 53092207 has travel speed: 25.1 km/h
# Edge from 53046255 to 53092203 has travel speed: 25.1 km/h
# Edge from 53050874 to 53092207 has travel speed: 25.1 km/h
# Edge from 53050874 to 53050875 has travel speed: 25.1 km/h
# Edge from 53050874 to 53046253 has travel speed: 25.1 km/h
# Edge from 53050875 to 53050874 has travel speed: 25.1 km/h
# Edge from 53050875 to 53092210 has travel speed: 25.1 km/h
# Edge from 53050875 to 53101285 has travel speed: 25.1 km/h
# Edge from 53057697 to 10747500178 has travel speed: 25.1 km/h
# Edge from 53057697 to 53062956 has travel speed: 40.2 km/h
# Edge from 53057697 to 53018410 has travel speed: 25.1 km/h
# Edge from 53059166 to 2286923094 has travel speed: 24.1 km/h
# Edge from 53059166 to 53059189 has travel speed: 25.1 km/h
# Edge from 53059166 to 53093365 has travel speed: 25.1 km/h
# Edge from 53059173 to 2286923088 has travel speed: 25.1 km/h
# Edge from 53059173 to 53093372 has travel speed: 25.1 km/h
# Edge from 53059173 to 53037307 has travel speed: 25.1 km/h
# Edge from 53059173 to 683050120 has travel speed: 25.1 km/h
# Edge from 53059175 to 245118288 has travel speed: 25.1 km/h
# Edge from 53059175 to 683050115 has travel speed: 25.1 km/h
# Edge from 53059175 to 53037307 has travel speed: 25.1 km/h
# Edge from 53059186 to 53059187 has travel speed: 25.1 km/h
# Edge from 53059186 to 53097586 has travel speed: 25.1 km/h
# Edge from 53059186 to 53118368 has travel speed: 25.1 km/h
# Edge from 53059187 to 53059189 has travel speed: 25.1 km/h
# Edge from 53059187 to 53059186 has travel speed: 25.1 km/h
# Edge from 53059187 to 53102808 has travel speed: 25.1 km/h
# Edge from 53059189 to 53059187 has travel speed: 25.1 km/h
# Edge from 53059189 to 53093372 has travel speed: 25.1 km/h
# Edge from 53059189 to 53059166 has travel speed: 25.1 km/h
# Edge from 53059885 to 256338428 has travel speed: 25.1 km/h
# Edge from 53059885 to 53149671 has travel speed: 24.1 km/h
# Edge from 53059885 to 9656853491 has travel speed: 24.1 km/h
# Edge from 53060462 to 53060465 has travel speed: 25.1 km/h
# Edge from 53060462 to 53089336 has travel speed: 25.1 km/h
# Edge from 53060462 to 53041668 has travel speed: 25.1 km/h
# Edge from 53060465 to 53060462 has travel speed: 25.1 km/h
# Edge from 53060465 to 53060466 has travel speed: 25.1 km/h
# Edge from 53060465 to 53093359 has travel speed: 25.1 km/h
# Edge from 53060466 to 53060467 has travel speed: 25.1 km/h
# Edge from 53060466 to 53060465 has travel speed: 25.1 km/h
# Edge from 53060466 to 53093360 has travel speed: 25.1 km/h
# Edge from 53060466 to 53113947 has travel speed: 25.1 km/h
# Edge from 53060467 to 53060468 has travel speed: 25.1 km/h
# Edge from 53060467 to 53060466 has travel speed: 25.1 km/h
# Edge from 53060467 to 53093362 has travel speed: 25.1 km/h
# Edge from 53060468 to 53060469 has travel speed: 25.1 km/h
# Edge from 53060468 to 53060467 has travel speed: 25.1 km/h
# Edge from 53060468 to 53078467 has travel speed: 40.2 km/h
# Edge from 53060468 to 53085385 has travel speed: 40.2 km/h
# Edge from 53060469 to 53078468 has travel speed: 25.1 km/h
# Edge from 53060469 to 53060471 has travel speed: 25.1 km/h
# Edge from 53060469 to 53142555 has travel speed: 25.1 km/h
# Edge from 53060469 to 53060468 has travel speed: 25.1 km/h
# Edge from 53060471 to 53078469 has travel speed: 25.1 km/h
# Edge from 53060471 to 53060473 has travel speed: 25.1 km/h
# Edge from 53060471 to 53060469 has travel speed: 25.1 km/h
# Edge from 53060471 to 53100813 has travel speed: 25.1 km/h
# Edge from 53060473 to 53060471 has travel speed: 25.1 km/h
# Edge from 53060473 to 53078473 has travel speed: 25.1 km/h
# Edge from 53060473 to 53078469 has travel speed: 25.1 km/h
# Edge from 53062956 to 10747500178 has travel speed: 25.1 km/h
# Edge from 53062956 to 53018410 has travel speed: 25.1 km/h
# Edge from 53062956 to 682821166 has travel speed: 40.2 km/h
# Edge from 53062956 to 53057697 has travel speed: 40.2 km/h
# Edge from 53062958 to 10747500178 has travel speed: 25.1 km/h
# Edge from 53062958 to 53145241 has travel speed: 40.2 km/h
# Edge from 53062958 to 53117166 has travel speed: 40.2 km/h
# Edge from 53064300 to 53064305 has travel speed: 25.1 km/h
# Edge from 53064300 to 53064302 has travel speed: 25.1 km/h
# Edge from 53064302 to 53064300 has travel speed: 25.1 km/h
# Edge from 53064302 to 53092220 has travel speed: 40.2 km/h
# Edge from 53064302 to 53092226 has travel speed: 40.2 km/h
# Edge from 53064305 to 53064300 has travel speed: 25.1 km/h
# Edge from 53064305 to 245384115 has travel speed: 40.2 km/h
# Edge from 53064305 to 53092220 has travel speed: 40.2 km/h
# Edge from 53064327 to 53075602 has travel speed: 25.1 km/h
# Edge from 53064327 to 53064328 has travel speed: 25.1 km/h
# Edge from 53064327 to 53017091 has travel speed: 25.1 km/h
# Edge from 53064328 to 53018404 has travel speed: 25.1 km/h
# Edge from 53064328 to 53064327 has travel speed: 25.1 km/h
# Edge from 53064328 to 53097980 has travel speed: 25.1 km/h
# Edge from 53064330 to 53064331 has travel speed: 25.1 km/h
# Edge from 53064330 to 4671607162 has travel speed: 44.3 km/h
# Edge from 53064330 to 53119160 has travel speed: 44.3 km/h
# Edge from 53064331 to 53076382 has travel speed: 40.2 km/h
# Edge from 53064331 to 53064330 has travel speed: 25.1 km/h
# Edge from 53064331 to 53119162 has travel speed: 40.2 km/h
# Edge from 53065783 to 53065785 has travel speed: 24.1 km/h
# Edge from 53065783 to 53099375 has travel speed: 24.1 km/h
# Edge from 53065783 to 53119042 has travel speed: 24.1 km/h
# Edge from 53065785 to 53065783 has travel speed: 24.1 km/h
# Edge from 53066716 to 53116276 has travel speed: 25.1 km/h
# Edge from 53066716 to 53066717 has travel speed: 25.1 km/h
# Edge from 53066717 to 683050066 has travel speed: 25.1 km/h
# Edge from 53066717 to 53066716 has travel speed: 25.1 km/h
# Edge from 53068822 to 53116276 has travel speed: 25.1 km/h
# Edge from 53068822 to 53068826 has travel speed: 25.1 km/h
# Edge from 53068822 to 53116302 has travel speed: 25.1 km/h
# Edge from 53068826 to 260707479 has travel speed: 25.1 km/h
# Edge from 53068826 to 260707482 has travel speed: 25.1 km/h
# Edge from 53068826 to 53068822 has travel speed: 25.1 km/h
# Edge from 53068826 to 686194326 has travel speed: 25.1 km/h
# Edge from 53068829 to 260707479 has travel speed: 25.1 km/h
# Edge from 53068829 to 53091598 has travel speed: 25.1 km/h
# Edge from 53073689 to 53085389 has travel speed: 40.2 km/h
# Edge from 53073689 to 53025060 has travel speed: 40.2 km/h
# Edge from 53073691 to 53073689 has travel speed: 25.1 km/h
# Edge from 53073691 to 53082627 has travel speed: 40.2 km/h
# Edge from 53073691 to 683050204 has travel speed: 25.1 km/h
# Edge from 53073691 to 53033660 has travel speed: 40.2 km/h
# Edge from 53073816 to 53044575 has travel speed: 25.1 km/h
# Edge from 53073816 to 53097586 has travel speed: 25.1 km/h
# Edge from 53073816 to 53097585 has travel speed: 25.1 km/h
# Edge from 53073822 to 53044575 has travel speed: 25.1 km/h
# Edge from 53073822 to 53118372 has travel speed: 25.1 km/h
# Edge from 53073822 to 53097585 has travel speed: 25.1 km/h
# Edge from 53073843 to 53152083 has travel speed: 40.2 km/h
# Edge from 53073843 to 53095909 has travel speed: 40.2 km/h
# Edge from 53074376 to 53074377 has travel speed: 25.1 km/h
# Edge from 53074376 to 53124803 has travel speed: 25.1 km/h
# Edge from 53074376 to 53118376 has travel speed: 25.1 km/h
# Edge from 53074377 to 53074380 has travel speed: 25.1 km/h
# Edge from 53074377 to 53074376 has travel speed: 25.1 km/h
# Edge from 53074377 to 53156140 has travel speed: 25.1 km/h
# Edge from 53074380 to 53074377 has travel speed: 25.1 km/h
# Edge from 53074380 to 53027459 has travel speed: 25.1 km/h
# Edge from 53074380 to 53134227 has travel speed: 25.1 km/h
# Edge from 53075311 to 256339663 has travel speed: 25.1 km/h
# Edge from 53075311 to 53092218 has travel speed: 24.1 km/h
# Edge from 53075311 to 53044661 has travel speed: 24.1 km/h
# Edge from 53075599 to 53017091 has travel speed: 25.1 km/h
# Edge from 53075599 to 53097976 has travel speed: 25.1 km/h
# Edge from 53075599 to 53097980 has travel speed: 40.2 km/h
# Edge from 53075602 to 53064327 has travel speed: 25.1 km/h
# Edge from 53075602 to 53075606 has travel speed: 25.1 km/h
# Edge from 53075606 to 53076244 has travel speed: 44.3 km/h
# Edge from 53075606 to 687156433 has travel speed: 25.1 km/h
# Edge from 53075606 to 53075602 has travel speed: 25.1 km/h
# Edge from 53076244 to 9124766429 has travel speed: 25.1 km/h
# Edge from 53076244 to 247141145 has travel speed: 44.3 km/h
# Edge from 53076245 to 53076246 has travel speed: 25.1 km/h
# Edge from 53076245 to 9124766429 has travel speed: 25.1 km/h
# Edge from 53076246 to 53076247 has travel speed: 25.1 km/h
# Edge from 53076246 to 53076245 has travel speed: 25.1 km/h
# Edge from 53076246 to 53123865 has travel speed: 25.1 km/h
# Edge from 53076247 to 2834093713 has travel speed: 25.1 km/h
# Edge from 53076247 to 53076246 has travel speed: 25.1 km/h
# Edge from 53076247 to 53124973 has travel speed: 25.1 km/h
# Edge from 53076250 to 53113946 has travel speed: 25.1 km/h
# Edge from 53076250 to 9124733144 has travel speed: 25.1 km/h
# Edge from 53076250 to 260707354 has travel speed: 25.1 km/h
# Edge from 53076382 to 53064331 has travel speed: 40.2 km/h
# Edge from 53076382 to 53076384 has travel speed: 25.1 km/h
# Edge from 53076382 to 53119160 has travel speed: 40.2 km/h
# Edge from 53076384 to 53076382 has travel speed: 25.1 km/h
# Edge from 53076384 to 53117160 has travel speed: 25.1 km/h
# Edge from 53076384 to 53076391 has travel speed: 25.1 km/h
# Edge from 53076384 to 53117098 has travel speed: 25.1 km/h
# Edge from 53076391 to 53076392 has travel speed: 25.1 km/h
# Edge from 53076391 to 53076384 has travel speed: 25.1 km/h
# Edge from 53076391 to 53117160 has travel speed: 25.1 km/h
# Edge from 53076392 to 53076391 has travel speed: 25.1 km/h
# Edge from 53076392 to 53100223 has travel speed: 25.1 km/h
# Edge from 53076395 to 53076399 has travel speed: 25.1 km/h
# Edge from 53076395 to 53100222 has travel speed: 25.1 km/h
# Edge from 53076399 to 53082643 has travel speed: 25.1 km/h
# Edge from 53076399 to 53128729 has travel speed: 25.1 km/h
# Edge from 53076399 to 53076395 has travel speed: 25.1 km/h
# Edge from 53077316 to 687156433 has travel speed: 25.1 km/h
# Edge from 53078467 to 53078468 has travel speed: 25.1 km/h
# Edge from 53078467 to 10684132265 has travel speed: 40.2 km/h
# Edge from 53078467 to 53060468 has travel speed: 40.2 km/h
# Edge from 53078468 to 53078469 has travel speed: 25.1 km/h
# Edge from 53078468 to 53060469 has travel speed: 25.1 km/h
# Edge from 53078468 to 53078467 has travel speed: 25.1 km/h
# Edge from 53078469 to 53078468 has travel speed: 25.1 km/h
# Edge from 53078469 to 53060471 has travel speed: 25.1 km/h
# Edge from 53078469 to 53060473 has travel speed: 25.1 km/h
# Edge from 53078473 to 956500319 has travel speed: 44.3 km/h
# Edge from 53078473 to 53100813 has travel speed: 44.3 km/h
# Edge from 53078473 to 53060473 has travel speed: 25.1 km/h
# Edge from 53078914 to 53018402 has travel speed: 25.1 km/h
# Edge from 53078914 to 53085009 has travel speed: 25.1 km/h
# Edge from 53078914 to 53018399 has travel speed: 25.1 km/h
# Edge from 53079888 to 4606504193 has travel speed: 25.1 km/h
# Edge from 53079888 to 53088882 has travel speed: 25.1 km/h
# Edge from 53079888 to 53088880 has travel speed: 25.1 km/h
# Edge from 53080198 to 256340150 has travel speed: 25.1 km/h
# Edge from 53080198 to 53092220 has travel speed: 25.1 km/h
# Edge from 53080198 to 53092218 has travel speed: 25.1 km/h
# Edge from 53081989 to 53114732 has travel speed: 25.1 km/h
# Edge from 53081989 to 53081990 has travel speed: 25.1 km/h
# Edge from 53081989 to 53114734 has travel speed: 25.1 km/h
# Edge from 53081990 to 53119164 has travel speed: 40.2 km/h
# Edge from 53081990 to 53081989 has travel speed: 25.1 km/h
# Edge from 53081990 to 53119162 has travel speed: 40.2 km/h
# Edge from 53082619 to 53082621 has travel speed: 25.1 km/h
# Edge from 53082619 to 53041445 has travel speed: 25.1 km/h
# Edge from 53082619 to 53125725 has travel speed: 25.1 km/h
# Edge from 53082621 to 53082619 has travel speed: 25.1 km/h
# Edge from 53082621 to 53082625 has travel speed: 24.1 km/h
# Edge from 53082621 to 53025057 has travel speed: 25.1 km/h
# Edge from 53082625 to 53082627 has travel speed: 24.1 km/h
# Edge from 53082625 to 2834814897 has travel speed: 24.1 km/h
# Edge from 53082627 to 53025060 has travel speed: 40.2 km/h
# Edge from 53082627 to 53073691 has travel speed: 40.2 km/h
# Edge from 53082632 to 317363251 has travel speed: 25.1 km/h
# Edge from 53082632 to 53082634 has travel speed: 25.1 km/h
# Edge from 53082632 to 2391023380 has travel speed: 25.1 km/h
# Edge from 53082634 to 53082632 has travel speed: 25.1 km/h
# Edge from 53082634 to 53082640 has travel speed: 25.1 km/h
# Edge from 53082634 to 53090322 has travel speed: 24.1 km/h
# Edge from 53082640 to 53082643 has travel speed: 25.1 km/h
# Edge from 53082640 to 53082634 has travel speed: 25.1 km/h
# Edge from 53082640 to 53157145 has travel speed: 25.1 km/h
# Edge from 53082643 to 53082644 has travel speed: 25.1 km/h
# Edge from 53082643 to 53076399 has travel speed: 25.1 km/h
# Edge from 53082643 to 53082640 has travel speed: 25.1 km/h
# Edge from 53082644 to 53082643 has travel speed: 25.1 km/h
# Edge from 53082644 to 686202982 has travel speed: 25.1 km/h
# Edge from 53082645 to 686202982 has travel speed: 25.1 km/h
# Edge from 53082645 to 53119164 has travel speed: 25.1 km/h
# Edge from 53082645 to 2833994093 has travel speed: 25.1 km/h
# Edge from 53085009 to 682821166 has travel speed: 25.1 km/h
# Edge from 53085009 to 53078914 has travel speed: 25.1 km/h
# Edge from 53085009 to 4671607162 has travel speed: 25.1 km/h
# Edge from 53085375 to 53085377 has travel speed: 25.1 km/h
# Edge from 53085375 to 53085377 has travel speed: 40.2 km/h
# Edge from 53085375 to 53040495 has travel speed: 40.2 km/h
# Edge from 53085377 to 53085375 has travel speed: 25.1 km/h
# Edge from 53085377 to 53085375 has travel speed: 40.2 km/h
# Edge from 53085377 to 53027454 has travel speed: 40.2 km/h
# Edge from 53085380 to 53027457 has travel speed: 25.1 km/h
# Edge from 53085380 to 53021750 has travel speed: 40.2 km/h
# Edge from 53085380 to 53027454 has travel speed: 40.2 km/h
# Edge from 53085382 to 683050221 has travel speed: 40.2 km/h
# Edge from 53085382 to 53152062 has travel speed: 40.2 km/h
# Edge from 53085382 to 53023513 has travel speed: 40.2 km/h
# Edge from 53085385 to 53060468 has travel speed: 40.2 km/h
# Edge from 53085385 to 53142555 has travel speed: 44.3 km/h
# Edge from 53085385 to 53111730 has travel speed: 44.3 km/h
# Edge from 53085387 to 10684132265 has travel speed: 40.2 km/h
# Edge from 53085387 to 53085388 has travel speed: 40.2 km/h
# Edge from 53085387 to 53093365 has travel speed: 25.1 km/h
# Edge from 53085388 to 53085387 has travel speed: 40.2 km/h
# Edge from 53085388 to 53102808 has travel speed: 25.1 km/h
# Edge from 53085388 to 53119168 has travel speed: 40.2 km/h
# Edge from 53085388 to 53085389 has travel speed: 40.2 km/h
# Edge from 53085389 to 53118366 has travel speed: 25.1 km/h
# Edge from 53085389 to 53073689 has travel speed: 40.2 km/h
# Edge from 53085389 to 53085388 has travel speed: 40.2 km/h
# Edge from 53086074 to 245118228 has travel speed: 25.1 km/h
# Edge from 53088880 to 53079888 has travel speed: 25.1 km/h
# Edge from 53088880 to 53092220 has travel speed: 40.2 km/h
# Edge from 53088880 to 53126000 has travel speed: 40.2 km/h
# Edge from 53088882 to 4606504193 has travel speed: 25.1 km/h
# Edge from 53088882 to 53079888 has travel speed: 25.1 km/h
# Edge from 53088882 to 53152921 has travel speed: 25.1 km/h
# Edge from 53089336 to 53042706 has travel speed: 25.1 km/h
# Edge from 53089336 to 53093359 has travel speed: 25.1 km/h
# Edge from 53089336 to 53060462 has travel speed: 25.1 km/h
# Edge from 53090322 to 53090323 has travel speed: 24.1 km/h
# Edge from 53090322 to 53082634 has travel speed: 24.1 km/h
# Edge from 53090322 to 53036557 has travel speed: 25.1 km/h
# Edge from 53090323 to 53090322 has travel speed: 24.1 km/h
# Edge from 53090323 to 260706808 has travel speed: 24.1 km/h
# Edge from 53090323 to 60755551 has travel speed: 24.1 km/h
# Edge from 53090940 to 370467066 has travel speed: 25.1 km/h
# Edge from 53090940 to 53125974 has travel speed: 25.1 km/h
# Edge from 53090940 to 53143485 has travel speed: 25.1 km/h
# Edge from 53091598 to 53116276 has travel speed: 25.1 km/h
# Edge from 53091598 to 53068829 has travel speed: 25.1 km/h
# Edge from 53092199 to 53092214 has travel speed: 25.1 km/h
# Edge from 53092199 to 53092201 has travel speed: 25.1 km/h
# Edge from 53092201 to 53092203 has travel speed: 25.1 km/h
# Edge from 53092201 to 53124807 has travel speed: 25.1 km/h
# Edge from 53092201 to 53092199 has travel speed: 25.1 km/h
# Edge from 53092201 to 246744892 has travel speed: 40.2 km/h
# Edge from 53092203 to 53092201 has travel speed: 25.1 km/h
# Edge from 53092203 to 53046255 has travel speed: 25.1 km/h
# Edge from 53092203 to 53133008 has travel speed: 25.1 km/h
# Edge from 53092207 to 53050874 has travel speed: 25.1 km/h
# Edge from 53092207 to 53092210 has travel speed: 25.1 km/h
# Edge from 53092207 to 53046255 has travel speed: 25.1 km/h
# Edge from 53092210 to 53050875 has travel speed: 25.1 km/h
# Edge from 53092210 to 53092207 has travel speed: 25.1 km/h
# Edge from 53092214 to 53092199 has travel speed: 25.1 km/h
# Edge from 53092214 to 53092218 has travel speed: 25.1 km/h
# Edge from 53092214 to 305541919 has travel speed: 25.1 km/h
# Edge from 53092218 to 53080198 has travel speed: 25.1 km/h
# Edge from 53092218 to 53092214 has travel speed: 25.1 km/h
# Edge from 53092218 to 53075311 has travel speed: 24.1 km/h
# Edge from 53092218 to 53126000 has travel speed: 25.1 km/h
# Edge from 53092220 to 53080198 has travel speed: 25.1 km/h
# Edge from 53092220 to 53088880 has travel speed: 40.2 km/h
# Edge from 53092220 to 53064302 has travel speed: 40.2 km/h
# Edge from 53092220 to 53064305 has travel speed: 40.2 km/h
# Edge from 53092226 to 53064302 has travel speed: 40.2 km/h
# Edge from 53093356 to 53119164 has travel speed: 25.1 km/h
# Edge from 53093356 to 53041442 has travel speed: 25.1 km/h
# Edge from 53093356 to 53114734 has travel speed: 25.1 km/h
# Edge from 53093359 to 53119166 has travel speed: 25.1 km/h
# Edge from 53093359 to 53060465 has travel speed: 25.1 km/h
# Edge from 53093359 to 53093360 has travel speed: 25.1 km/h
# Edge from 53093359 to 53089336 has travel speed: 25.1 km/h
# Edge from 53093360 to 53119168 has travel speed: 25.1 km/h
# Edge from 53093360 to 53060466 has travel speed: 25.1 km/h
# Edge from 53093360 to 53093362 has travel speed: 25.1 km/h
# Edge from 53093360 to 53093359 has travel speed: 25.1 km/h
# Edge from 53093362 to 10684132265 has travel speed: 25.1 km/h
# Edge from 53093362 to 53060467 has travel speed: 25.1 km/h
# Edge from 53093362 to 53093360 has travel speed: 25.1 km/h
# Edge from 53093365 to 53059166 has travel speed: 25.1 km/h
# Edge from 53093365 to 53085387 has travel speed: 25.1 km/h
# Edge from 53093365 to 53025220 has travel speed: 25.1 km/h
# Edge from 53093372 to 53037306 has travel speed: 25.1 km/h
# Edge from 53093372 to 53059189 has travel speed: 25.1 km/h
# Edge from 53093372 to 53059173 has travel speed: 25.1 km/h
# Edge from 53095909 to 53036557 has travel speed: 25.1 km/h
# Edge from 53095909 to 53036558 has travel speed: 40.2 km/h
# Edge from 53095909 to 53073843 has travel speed: 40.2 km/h
# Edge from 53097380 to 245118228 has travel speed: 25.1 km/h
# Edge from 53097380 to 245118387 has travel speed: 25.1 km/h
# Edge from 53097585 to 53073816 has travel speed: 25.1 km/h
# Edge from 53097585 to 53073822 has travel speed: 25.1 km/h
# Edge from 53097585 to 53118368 has travel speed: 25.1 km/h
# Edge from 53097586 to 53073816 has travel speed: 25.1 km/h
# Edge from 53097586 to 53126347 has travel speed: 25.1 km/h
# Edge from 53097586 to 53059186 has travel speed: 25.1 km/h
# Edge from 53097976 to 53040794 has travel speed: 25.1 km/h
# Edge from 53097976 to 53097980 has travel speed: 25.1 km/h
# Edge from 53097980 to 53064328 has travel speed: 25.1 km/h
# Edge from 53097980 to 53018397 has travel speed: 40.2 km/h
# Edge from 53097980 to 53075599 has travel speed: 40.2 km/h
# Edge from 53099375 to 3905291938 has travel speed: 24.1 km/h
# Edge from 53099375 to 53065783 has travel speed: 24.1 km/h
# Edge from 53100222 to 53076392 has travel speed: 25.1 km/h
# Edge from 53100222 to 53155115 has travel speed: 25.1 km/h
# Edge from 53100223 to 53076395 has travel speed: 25.1 km/h
# Edge from 53100223 to 686203266 has travel speed: 25.1 km/h
# Edge from 53100813 to 53060471 has travel speed: 25.1 km/h
# Edge from 53100813 to 53142555 has travel speed: 44.3 km/h
# Edge from 53100813 to 53078473 has travel speed: 44.3 km/h
# Edge from 53101282 to 53101285 has travel speed: 25.1 km/h
# Edge from 53101282 to 53046252 has travel speed: 25.1 km/h
# Edge from 53101282 to 53142908 has travel speed: 24.1 km/h
# Edge from 53101285 to 53050875 has travel speed: 25.1 km/h
# Edge from 53101285 to 53101282 has travel speed: 25.1 km/h
# Edge from 53101285 to 53142908 has travel speed: 25.1 km/h
# Edge from 53102808 to 53025220 has travel speed: 25.1 km/h
# Edge from 53102808 to 53059187 has travel speed: 25.1 km/h
# Edge from 53102808 to 53085388 has travel speed: 25.1 km/h
# Edge from 53107191 to 311882161 has travel speed: 25.1 km/h
# Edge from 53107191 to 311884105 has travel speed: 44.3 km/h
# Edge from 53107191 to 53114726 has travel speed: 44.3 km/h
# Edge from 53107192 to 311882161 has travel speed: 25.1 km/h
# Edge from 53107192 to 53123865 has travel speed: 25.1 km/h
# Edge from 53107192 to 53076245 has travel speed: 25.1 km/h
# Edge from 53108990 to 53108992 has travel speed: 25.1 km/h
# Edge from 53108990 to 53118374 has travel speed: 25.1 km/h
# Edge from 53108990 to 53118372 has travel speed: 25.1 km/h
# Edge from 53108992 to 53108990 has travel speed: 25.1 km/h
# Edge from 53108992 to 53126350 has travel speed: 25.1 km/h
# Edge from 53108992 to 53126347 has travel speed: 25.1 km/h
# Edge from 53111728 to 53111730 has travel speed: 25.1 km/h
# Edge from 53111728 to 53113947 has travel speed: 25.1 km/h
# Edge from 53111728 to 53113946 has travel speed: 25.1 km/h
# Edge from 53111730 to 53111728 has travel speed: 25.1 km/h
# Edge from 53111730 to 53085385 has travel speed: 44.3 km/h
# Edge from 53111730 to 53113947 has travel speed: 25.1 km/h
# Edge from 53112467 to 53112473 has travel speed: 25.1 km/h
# Edge from 53112467 to 245118288 has travel speed: 25.1 km/h
# Edge from 53112467 to 245118772 has travel speed: 25.1 km/h
# Edge from 53112473 to 53112476 has travel speed: 25.1 km/h
# Edge from 53112473 to 53112467 has travel speed: 25.1 km/h
# Edge from 53112473 to 53148306 has travel speed: 25.1 km/h
# Edge from 53112476 to 53112473 has travel speed: 25.1 km/h
# Edge from 53112476 to 53118380 has travel speed: 25.1 km/h
# Edge from 53112476 to 53118376 has travel speed: 25.1 km/h
# Edge from 53113943 to 53137611 has travel speed: 25.1 km/h
# Edge from 53113943 to 247141128 has travel speed: 25.1 km/h
# Edge from 53113943 to 53113946 has travel speed: 25.1 km/h
# Edge from 53113946 to 53076250 has travel speed: 25.1 km/h
# Edge from 53113946 to 53111728 has travel speed: 25.1 km/h
# Edge from 53113946 to 53137611 has travel speed: 25.1 km/h
# Edge from 53113946 to 53113943 has travel speed: 25.1 km/h
# Edge from 53113947 to 53111728 has travel speed: 25.1 km/h
# Edge from 53113947 to 53060466 has travel speed: 25.1 km/h
# Edge from 53113947 to 53111730 has travel speed: 25.1 km/h
# Edge from 53114726 to 4671607162 has travel speed: 44.3 km/h
# Edge from 53114726 to 53018404 has travel speed: 25.1 km/h
# Edge from 53114726 to 53114727 has travel speed: 25.1 km/h
# Edge from 53114726 to 53107191 has travel speed: 44.3 km/h
# Edge from 53114727 to 53114730 has travel speed: 25.1 km/h
# Edge from 53114727 to 53114726 has travel speed: 25.1 km/h
# Edge from 53114727 to 53119162 has travel speed: 25.1 km/h
# Edge from 53114730 to 53114732 has travel speed: 25.1 km/h
# Edge from 53114730 to 53114727 has travel speed: 25.1 km/h
# Edge from 53114730 to 53123865 has travel speed: 25.1 km/h
# Edge from 53114732 to 53081989 has travel speed: 25.1 km/h
# Edge from 53114732 to 53114730 has travel speed: 25.1 km/h
# Edge from 53114732 to 53124973 has travel speed: 25.1 km/h
# Edge from 53114734 to 53093356 has travel speed: 25.1 km/h
# Edge from 53114734 to 53041440 has travel speed: 25.1 km/h
# Edge from 53114734 to 53081989 has travel speed: 25.1 km/h
# Edge from 53115407 to 2834816916 has travel speed: 25.1 km/h
# Edge from 53115407 to 53041440 has travel speed: 25.1 km/h
# Edge from 53115407 to 2834093713 has travel speed: 25.1 km/h
# Edge from 53116276 to 53068822 has travel speed: 25.1 km/h
# Edge from 53116276 to 53091598 has travel speed: 25.1 km/h
# Edge from 53116276 to 53066716 has travel speed: 25.1 km/h
# Edge from 53116302 to 53116304 has travel speed: 25.1 km/h
# Edge from 53116302 to 53068822 has travel speed: 25.1 km/h
# Edge from 53116302 to 53122757 has travel speed: 25.1 km/h
# Edge from 53116304 to 53116302 has travel speed: 25.1 km/h
# Edge from 53116661 to 245386862 has travel speed: 40.2 km/h
# Edge from 53116661 to 53116662 has travel speed: 25.1 km/h
# Edge from 53116661 to 245384115 has travel speed: 40.2 km/h
# Edge from 53116662 to 53116664 has travel speed: 25.1 km/h
# Edge from 53116662 to 245384115 has travel speed: 25.1 km/h
# Edge from 53116662 to 53116661 has travel speed: 25.1 km/h
# Edge from 53116664 to 53116672 has travel speed: 25.1 km/h
# Edge from 53116664 to 53116662 has travel speed: 25.1 km/h
# Edge from 53116664 to 245387557 has travel speed: 25.1 km/h
# Edge from 53116672 to 53146451 has travel speed: 25.1 km/h
# Edge from 53116672 to 53116664 has travel speed: 25.1 km/h
# Edge from 53116672 to 245387832 has travel speed: 25.1 km/h
# Edge from 53117097 to 53128727 has travel speed: 25.1 km/h
# Edge from 53117097 to 53119162 has travel speed: 25.1 km/h
# Edge from 53117097 to 53117098 has travel speed: 25.1 km/h
# Edge from 53117098 to 53155115 has travel speed: 25.1 km/h
# Edge from 53117098 to 53076384 has travel speed: 25.1 km/h
# Edge from 53117098 to 53117097 has travel speed: 25.1 km/h
# Edge from 53117160 to 53076384 has travel speed: 25.1 km/h
# Edge from 53117160 to 53076391 has travel speed: 25.1 km/h
# Edge from 53117160 to 53117166 has travel speed: 25.1 km/h
# Edge from 53117166 to 53062958 has travel speed: 40.2 km/h
# Edge from 53117166 to 53117160 has travel speed: 25.1 km/h
# Edge from 53118296 to 53118299 has travel speed: 25.1 km/h
# Edge from 53118296 to 53044664 has travel speed: 25.1 km/h
# Edge from 53118296 to 53143485 has travel speed: 25.1 km/h
# Edge from 53118299 to 53118296 has travel speed: 25.1 km/h
# Edge from 53118299 to 53041437 has travel speed: 40.2 km/h
# Edge from 53118299 to 53125575 has travel speed: 40.2 km/h
# Edge from 53118366 to 53118368 has travel speed: 25.1 km/h
# Edge from 53118366 to 683050204 has travel speed: 25.1 km/h
# Edge from 53118366 to 53085389 has travel speed: 25.1 km/h
# Edge from 53118368 to 53097585 has travel speed: 25.1 km/h
# Edge from 53118368 to 53118366 has travel speed: 25.1 km/h
# Edge from 53118368 to 53059186 has travel speed: 25.1 km/h
# Edge from 53118372 to 53108990 has travel speed: 25.1 km/h
# Edge from 53118372 to 53073822 has travel speed: 25.1 km/h
# Edge from 53118372 to 53134227 has travel speed: 25.1 km/h
# Edge from 53118374 to 53118376 has travel speed: 25.1 km/h
# Edge from 53118374 to 53156140 has travel speed: 25.1 km/h
# Edge from 53118374 to 53108990 has travel speed: 25.1 km/h
# Edge from 53118376 to 53074376 has travel speed: 25.1 km/h
# Edge from 53118376 to 53118374 has travel speed: 25.1 km/h
# Edge from 53118376 to 53112476 has travel speed: 25.1 km/h
# Edge from 53118380 to 53126350 has travel speed: 25.1 km/h
# Edge from 53118380 to 683050115 has travel speed: 25.1 km/h
# Edge from 53118380 to 53112476 has travel speed: 25.1 km/h
# Edge from 53119042 to 256543149 has travel speed: 24.1 km/h
# Edge from 53119042 to 53065783 has travel speed: 24.1 km/h
# Edge from 53119042 to 11036463561 has travel speed: 24.1 km/h
# Edge from 53119160 to 53076382 has travel speed: 40.2 km/h
# Edge from 53119160 to 53064330 has travel speed: 44.3 km/h
# Edge from 53119160 to 682821166 has travel speed: 40.2 km/h
# Edge from 53119160 to 53145241 has travel speed: 40.2 km/h
# Edge from 53119162 to 53081990 has travel speed: 40.2 km/h
# Edge from 53119162 to 53064331 has travel speed: 40.2 km/h
# Edge from 53119162 to 53117097 has travel speed: 25.1 km/h
# Edge from 53119162 to 53114727 has travel speed: 25.1 km/h
# Edge from 53119164 to 53081990 has travel speed: 40.2 km/h
# Edge from 53119164 to 53093356 has travel speed: 25.1 km/h
# Edge from 53119164 to 53041443 has travel speed: 40.2 km/h
# Edge from 53119164 to 686202982 has travel speed: 25.1 km/h
# Edge from 53119166 to 53025057 has travel speed: 25.1 km/h
# Edge from 53119166 to 53093359 has travel speed: 25.1 km/h
# Edge from 53119166 to 53119168 has travel speed: 40.2 km/h
# Edge from 53119166 to 53042707 has travel speed: 40.2 km/h
# Edge from 53119168 to 2834814897 has travel speed: 25.1 km/h
# Edge from 53119168 to 53093360 has travel speed: 25.1 km/h
# Edge from 53119168 to 53085388 has travel speed: 40.2 km/h
# Edge from 53119168 to 53119166 has travel speed: 40.2 km/h
# Edge from 53122757 to 53116302 has travel speed: 25.1 km/h
# Edge from 53122757 to 53023513 has travel speed: 40.2 km/h
# Edge from 53122757 to 317339074 has travel speed: 40.2 km/h
# Edge from 53123865 to 53114730 has travel speed: 25.1 km/h
# Edge from 53123865 to 53076246 has travel speed: 25.1 km/h
# Edge from 53123865 to 53124973 has travel speed: 25.1 km/h
# Edge from 53123865 to 53107192 has travel speed: 25.1 km/h
# Edge from 53124803 to 53074376 has travel speed: 25.1 km/h
# Edge from 53124803 to 53127240 has travel speed: 25.1 km/h
# Edge from 53124803 to 53124805 has travel speed: 25.1 km/h
# Edge from 53124805 to 53124807 has travel speed: 25.1 km/h
# Edge from 53124805 to 53124803 has travel speed: 25.1 km/h
# Edge from 53124805 to 2518218246 has travel speed: 40.2 km/h
# Edge from 53124805 to 53125997 has travel speed: 40.2 km/h
# Edge from 53124807 to 53092201 has travel speed: 25.1 km/h
# Edge from 53124807 to 53124805 has travel speed: 25.1 km/h
# Edge from 53124807 to 53133008 has travel speed: 25.1 km/h
# Edge from 53124973 to 53123865 has travel speed: 25.1 km/h
# Edge from 53124973 to 53114732 has travel speed: 25.1 km/h
# Edge from 53124973 to 53076247 has travel speed: 25.1 km/h
# Edge from 53125573 to 53125575 has travel speed: 25.1 km/h
# Edge from 53125573 to 53144229 has travel speed: 25.1 km/h
# Edge from 53125573 to 53144226 has travel speed: 25.1 km/h
# Edge from 53125575 to 53125573 has travel speed: 25.1 km/h
# Edge from 53125575 to 53118299 has travel speed: 40.2 km/h
# Edge from 53125575 to 53144229 has travel speed: 40.2 km/h
# Edge from 53125725 to 53082619 has travel speed: 25.1 km/h
# Edge from 53125973 to 245387832 has travel speed: 25.1 km/h
# Edge from 53125973 to 53125974 has travel speed: 40.2 km/h
# Edge from 53125973 to 245386862 has travel speed: 40.2 km/h
# Edge from 53125974 to 53090940 has travel speed: 25.1 km/h
# Edge from 53125974 to 53041432 has travel speed: 40.2 km/h
# Edge from 53125974 to 53125973 has travel speed: 40.2 km/h
# Edge from 53125997 to 53133008 has travel speed: 25.1 km/h
# Edge from 53125997 to 53127240 has travel speed: 25.1 km/h
# Edge from 53125997 to 53124805 has travel speed: 40.2 km/h
# Edge from 53125997 to 53046251 has travel speed: 40.2 km/h
# Edge from 53125999 to 2518218246 has travel speed: 40.2 km/h
# Edge from 53125999 to 305541919 has travel speed: 25.1 km/h
# Edge from 53125999 to 53126000 has travel speed: 40.2 km/h
# Edge from 53126000 to 53088880 has travel speed: 40.2 km/h
# Edge from 53126000 to 53092218 has travel speed: 25.1 km/h
# Edge from 53126000 to 53125999 has travel speed: 40.2 km/h
# Edge from 53126347 to 53097586 has travel speed: 25.1 km/h
# Edge from 53126347 to 53108992 has travel speed: 25.1 km/h
# Edge from 53126347 to 53126350 has travel speed: 25.1 km/h
# Edge from 53126350 to 53118380 has travel speed: 25.1 km/h
# Edge from 53126350 to 53108992 has travel speed: 25.1 km/h
# Edge from 53126350 to 53126347 has travel speed: 25.1 km/h
# Edge from 53127240 to 53124803 has travel speed: 25.1 km/h
# Edge from 53127240 to 53046249 has travel speed: 25.1 km/h
# Edge from 53127240 to 53125997 has travel speed: 25.1 km/h
# Edge from 53128727 to 53128729 has travel speed: 25.1 km/h
# Edge from 53128727 to 53117097 has travel speed: 25.1 km/h
# Edge from 53128727 to 53155115 has travel speed: 25.1 km/h
# Edge from 53128729 to 53076399 has travel speed: 25.1 km/h
# Edge from 53128729 to 53128727 has travel speed: 25.1 km/h
# Edge from 53128729 to 53134176 has travel speed: 25.1 km/h
# Edge from 53128733 to 53082644 has travel speed: 25.1 km/h
# Edge from 53128733 to 2834031502 has travel speed: 25.1 km/h
# Edge from 53133008 to 53092203 has travel speed: 25.1 km/h
# Edge from 53133008 to 53125997 has travel speed: 25.1 km/h
# Edge from 53133008 to 53124807 has travel speed: 25.1 km/h
# Edge from 53133008 to 53046254 has travel speed: 25.1 km/h
# Edge from 53134176 to 53128729 has travel speed: 25.1 km/h
# Edge from 53134227 to 2391023402 has travel speed: 25.1 km/h
# Edge from 53134227 to 53118372 has travel speed: 25.1 km/h
# Edge from 53134227 to 53074380 has travel speed: 25.1 km/h
# Edge from 53137611 to 53113943 has travel speed: 25.1 km/h
# Edge from 53137611 to 53113946 has travel speed: 25.1 km/h
# Edge from 53140452 to 956500319 has travel speed: 36.5 km/h
# Edge from 53140452 to 442842707 has travel speed: 36.5 km/h
# Edge from 53140454 to 956500319 has travel speed: 44.3 km/h
# Edge from 53140454 to 53140452 has travel speed: 36.5 km/h
# Edge from 53140454 to 256543149 has travel speed: 44.3 km/h
# Edge from 53142555 to 53060469 has travel speed: 25.1 km/h
# Edge from 53142555 to 53085385 has travel speed: 44.3 km/h
# Edge from 53142555 to 53100813 has travel speed: 44.3 km/h
# Edge from 53142908 to 53156410 has travel speed: 24.1 km/h
# Edge from 53142908 to 53101282 has travel speed: 24.1 km/h
# Edge from 53143484 to 53143485 has travel speed: 25.1 km/h
# Edge from 53143485 to 53143484 has travel speed: 25.1 km/h
# Edge from 53143485 to 53118296 has travel speed: 25.1 km/h
# Edge from 53143485 to 53090940 has travel speed: 25.1 km/h
# Edge from 53144226 to 683790465 has travel speed: 25.1 km/h
# Edge from 53144226 to 53125573 has travel speed: 25.1 km/h
# Edge from 53144226 to 53044664 has travel speed: 25.1 km/h
# Edge from 53144229 to 53125573 has travel speed: 25.1 km/h
# Edge from 53144229 to 53125575 has travel speed: 40.2 km/h
# Edge from 53144229 to 683790519 has travel speed: 40.2 km/h
# Edge from 53145205 to 10232094660 has travel speed: 25.1 km/h
# Edge from 53145205 to 683790735 has travel speed: 40.2 km/h
# Edge from 53145205 to 53041437 has travel speed: 40.2 km/h
# Edge from 53145241 to 53119160 has travel speed: 40.2 km/h
# Edge from 53145241 to 53018411 has travel speed: 40.2 km/h
# Edge from 53145241 to 53062958 has travel speed: 40.2 km/h
# Edge from 53146451 to 53116672 has travel speed: 25.1 km/h
# Edge from 53148306 to 53112473 has travel speed: 25.1 km/h
# Edge from 53149343 to 10677487586 has travel speed: 25.1 km/h
# Edge from 53149671 to 53149673 has travel speed: 25.1 km/h
# Edge from 53149671 to 53059885 has travel speed: 24.1 km/h
# Edge from 53149671 to 256338813 has travel speed: 24.1 km/h
# Edge from 53149673 to 53149671 has travel speed: 25.1 km/h
# Edge from 53152062 to 53027463 has travel speed: 40.2 km/h
# Edge from 53152062 to 53156408 has travel speed: 24.1 km/h
# Edge from 53152062 to 53085382 has travel speed: 40.2 km/h
# Edge from 53152069 to 53152083 has travel speed: 40.2 km/h
# Edge from 53152069 to 53073843 has travel speed: 40.2 km/h
# Edge from 53152083 to 53073843 has travel speed: 40.2 km/h
# Edge from 53152083 to 53152069 has travel speed: 40.2 km/h
# Edge from 53152083 to 9231102999 has travel speed: 25.1 km/h
# Edge from 53152921 to 53088882 has travel speed: 25.1 km/h
# Edge from 53155115 to 53117098 has travel speed: 25.1 km/h
# Edge from 53155115 to 53128727 has travel speed: 25.1 km/h
# Edge from 53155115 to 53100222 has travel speed: 25.1 km/h
# Edge from 53156140 to 53156142 has travel speed: 25.1 km/h
# Edge from 53156140 to 53074377 has travel speed: 25.1 km/h
# Edge from 53156140 to 53118374 has travel speed: 25.1 km/h
# Edge from 53156142 to 53156140 has travel speed: 25.1 km/h
# Edge from 53156408 to 53156410 has travel speed: 24.1 km/h
# Edge from 53156408 to 53152062 has travel speed: 24.1 km/h
# Edge from 53156408 to 53156415 has travel speed: 24.1 km/h
# Edge from 53156410 to 53156408 has travel speed: 24.1 km/h
# Edge from 53156410 to 53156415 has travel speed: 24.1 km/h
# Edge from 53156410 to 53142908 has travel speed: 24.1 km/h
# Edge from 53156415 to 53156417 has travel speed: 24.1 km/h
# Edge from 53156415 to 53156410 has travel speed: 24.1 km/h
# Edge from 53156415 to 53156408 has travel speed: 24.1 km/h
# Edge from 53156417 to 53156415 has travel speed: 24.1 km/h
# Edge from 53156417 to 53156417 has travel speed: 24.1 km/h
# Edge from 53156417 to 53156417 has travel speed: 24.1 km/h
# Edge from 53157145 to 53082640 has travel speed: 25.1 km/h
# Edge from 60755551 to 53090323 has travel speed: 24.1 km/h
# Edge from 60755551 to 53036558 has travel speed: 24.1 km/h
# Edge from 60755551 to 53036557 has travel speed: 25.1 km/h
# Edge from 245118228 to 53097380 has travel speed: 25.1 km/h
# Edge from 245118228 to 53086074 has travel speed: 25.1 km/h
# Edge from 245118228 to 245118387 has travel speed: 25.1 km/h
# Edge from 245118288 to 245118387 has travel speed: 25.1 km/h
# Edge from 245118288 to 53059175 has travel speed: 25.1 km/h
# Edge from 245118288 to 53112467 has travel speed: 25.1 km/h
# Edge from 245118387 to 245118228 has travel speed: 25.1 km/h
# Edge from 245118387 to 245118288 has travel speed: 25.1 km/h
# Edge from 245118387 to 53097380 has travel speed: 25.1 km/h
# Edge from 245118772 to 53112467 has travel speed: 25.1 km/h
# Edge from 245384115 to 53116662 has travel speed: 25.1 km/h
# Edge from 245384115 to 53116661 has travel speed: 40.2 km/h
# Edge from 245384115 to 53064305 has travel speed: 40.2 km/h
# Edge from 245386862 to 245387557 has travel speed: 25.1 km/h
# Edge from 245386862 to 53125973 has travel speed: 40.2 km/h
# Edge from 245386862 to 53116661 has travel speed: 40.2 km/h
# Edge from 245387557 to 245386862 has travel speed: 25.1 km/h
# Edge from 245387557 to 245387832 has travel speed: 25.1 km/h
# Edge from 245387557 to 53116664 has travel speed: 25.1 km/h
# Edge from 245387832 to 245387557 has travel speed: 25.1 km/h
# Edge from 245387832 to 53116672 has travel speed: 25.1 km/h
# Edge from 245387832 to 53125973 has travel speed: 25.1 km/h
# Edge from 245505298 to 683790735 has travel speed: 40.2 km/h
# Edge from 245505298 to 53041432 has travel speed: 40.2 km/h
# Edge from 245505820 to 245505298 has travel speed: 25.1 km/h
# Edge from 245505820 to 53041437 has travel speed: 25.1 km/h
# Edge from 245523440 to 53035698 has travel speed: 56.3 km/h
# Edge from 246744892 to 53092201 has travel speed: 40.2 km/h
# Edge from 247141128 to 53113943 has travel speed: 25.1 km/h
# Edge from 247141128 to 687156433 has travel speed: 25.1 km/h
# Edge from 247141145 to 9124766429 has travel speed: 44.3 km/h
# Edge from 247141145 to 311884105 has travel speed: 44.3 km/h
# Edge from 256338428 to 53059885 has travel speed: 25.1 km/h
# Edge from 256338808 to 2890584258 has travel speed: 24.1 km/h
# Edge from 256338808 to 256338809 has travel speed: 24.1 km/h
# Edge from 256338809 to 256338812 has travel speed: 24.1 km/h
# Edge from 256338809 to 256338808 has travel speed: 24.1 km/h
# Edge from 256338809 to 256338808 has travel speed: 25.1 km/h
# Edge from 256338812 to 256338813 has travel speed: 24.1 km/h
# Edge from 256338812 to 256338813 has travel speed: 25.1 km/h
# Edge from 256338812 to 256338809 has travel speed: 24.1 km/h
# Edge from 256338813 to 256338812 has travel speed: 24.1 km/h
# Edge from 256338813 to 53149671 has travel speed: 24.1 km/h
# Edge from 256339663 to 53075311 has travel speed: 25.1 km/h
# Edge from 256340150 to 53080198 has travel speed: 25.1 km/h
# Edge from 256543149 to 53119042 has travel speed: 24.1 km/h
# Edge from 256543149 to 53140454 has travel speed: 44.3 km/h
# Edge from 260706808 to 53090323 has travel speed: 24.1 km/h
# Edge from 260707354 to 2834093713 has travel speed: 25.1 km/h
# Edge from 260707354 to 9124733144 has travel speed: 25.1 km/h
# Edge from 260707354 to 53076250 has travel speed: 25.1 km/h
# Edge from 260707479 to 53068826 has travel speed: 25.1 km/h
# Edge from 260707479 to 260707482 has travel speed: 25.1 km/h
# Edge from 260707479 to 53068829 has travel speed: 25.1 km/h
# Edge from 260707482 to 53068826 has travel speed: 25.1 km/h
# Edge from 260707482 to 260707479 has travel speed: 25.1 km/h
# Edge from 260707482 to 10677487586 has travel speed: 25.1 km/h
# Edge from 305541020 to 53085377 has travel speed: 36.5 km/h
# Edge from 305541020 to 53027454 has travel speed: 25.1 km/h
# Edge from 305541020 to 53027455 has travel speed: 25.1 km/h
# Edge from 305541919 to 53092214 has travel speed: 25.1 km/h
# Edge from 305541919 to 53125999 has travel speed: 25.1 km/h
# Edge from 311882161 to 53107192 has travel speed: 25.1 km/h
# Edge from 311882161 to 311884105 has travel speed: 25.1 km/h
# Edge from 311884105 to 311882161 has travel speed: 25.1 km/h
# Edge from 311884105 to 53107191 has travel speed: 44.3 km/h
# Edge from 311884105 to 247141145 has travel speed: 44.3 km/h
# Edge from 317339074 to 53122757 has travel speed: 40.2 km/h
# Edge from 317339074 to 53036558 has travel speed: 40.2 km/h
# Edge from 317363251 to 53082632 has travel speed: 25.1 km/h
# Edge from 317364095 to 53022623 has travel speed: 25.1 km/h
# Edge from 370467066 to 53090940 has travel speed: 25.1 km/h
# Edge from 370467066 to 370467066 has travel speed: 25.1 km/h
# Edge from 370467066 to 370467066 has travel speed: 25.1 km/h
# Edge from 432431093 to 53033660 has travel speed: 25.1 km/h
# Edge from 442842707 to 53140452 has travel speed: 36.5 km/h
# Edge from 682821166 to 53085009 has travel speed: 25.1 km/h
# Edge from 682821166 to 53119160 has travel speed: 40.2 km/h
# Edge from 682821166 to 53062956 has travel speed: 40.2 km/h
# Edge from 682931951 to 10879933448 has travel speed: 40.2 km/h
# Edge from 682931951 to 317339074 has travel speed: 25.1 km/h
# Edge from 683050066 to 53066717 has travel speed: 25.1 km/h
# Edge from 683050115 to 53037306 has travel speed: 25.1 km/h
# Edge from 683050115 to 53118380 has travel speed: 25.1 km/h
# Edge from 683050115 to 53059175 has travel speed: 25.1 km/h
# Edge from 683050120 to 53059173 has travel speed: 25.1 km/h
# Edge from 683050120 to 2286923088 has travel speed: 25.1 km/h
# Edge from 683050204 to 53118366 has travel speed: 25.1 km/h
# Edge from 683050204 to 53033660 has travel speed: 25.1 km/h
# Edge from 683050204 to 53073691 has travel speed: 25.1 km/h
# Edge from 683050219 to 53021742 has travel speed: 25.1 km/h
# Edge from 683050219 to 53023513 has travel speed: 25.1 km/h
# Edge from 683050219 to 683050221 has travel speed: 25.1 km/h
# Edge from 683050221 to 53085382 has travel speed: 40.2 km/h
# Edge from 683050221 to 53021750 has travel speed: 40.2 km/h
# Edge from 683790465 to 53144226 has travel speed: 25.1 km/h
# Edge from 683790519 to 53144229 has travel speed: 40.2 km/h
# Edge from 683790735 to 53145205 has travel speed: 40.2 km/h
# Edge from 683790735 to 245505298 has travel speed: 40.2 km/h
# Edge from 686194326 to 53068826 has travel speed: 25.1 km/h
# Edge from 686202982 to 53082645 has travel speed: 25.1 km/h
# Edge from 686202982 to 53082644 has travel speed: 25.1 km/h
# Edge from 686203266 to 53100223 has travel speed: 25.1 km/h
# Edge from 686203266 to 9231102999 has travel speed: 25.1 km/h
# Edge from 687156433 to 247141128 has travel speed: 25.1 km/h
# Edge from 687156433 to 53077316 has travel speed: 25.1 km/h
# Edge from 687156433 to 53075606 has travel speed: 25.1 km/h
# Edge from 703006798 to 53035698 has travel speed: 40.2 km/h
# Edge from 956500319 to 53140454 has travel speed: 44.3 km/h
# Edge from 956500319 to 53140452 has travel speed: 36.5 km/h
# Edge from 956500319 to 53078473 has travel speed: 44.3 km/h
# Edge from 2286923088 to 2286923094 has travel speed: 25.1 km/h
# Edge from 2286923088 to 53059173 has travel speed: 25.1 km/h
# Edge from 2286923094 to 53059166 has travel speed: 24.1 km/h
# Edge from 2286923094 to 683050120 has travel speed: 25.1 km/h
# Edge from 2391023380 to 53082632 has travel speed: 25.1 km/h
# Edge from 2391023380 to 9231102999 has travel speed: 25.1 km/h
# Edge from 2391023380 to 686203266 has travel speed: 25.1 km/h
# Edge from 2391023394 to 53027459 has travel speed: 25.1 km/h
# Edge from 2391023394 to 2391023402 has travel speed: 25.1 km/h
# Edge from 2391023394 to 53027457 has travel speed: 25.1 km/h
# Edge from 2391023402 to 53134227 has travel speed: 25.1 km/h
# Edge from 2391023402 to 53027457 has travel speed: 25.1 km/h
# Edge from 2518218246 to 305541919 has travel speed: 25.1 km/h
# Edge from 2518218246 to 53124805 has travel speed: 40.2 km/h
# Edge from 2518218246 to 53125999 has travel speed: 40.2 km/h
# Edge from 2833994093 to 53128733 has travel speed: 25.1 km/h
# Edge from 2833994093 to 53041445 has travel speed: 25.1 km/h
# Edge from 2833994093 to 53082645 has travel speed: 25.1 km/h
# Edge from 2834031502 to 53128733 has travel speed: 25.1 km/h
# Edge from 2834093713 to 53076247 has travel speed: 25.1 km/h
# Edge from 2834093713 to 260707354 has travel speed: 25.1 km/h
# Edge from 2834093713 to 53115407 has travel speed: 25.1 km/h
# Edge from 2834814897 to 53025060 has travel speed: 25.1 km/h
# Edge from 2834814897 to 53025057 has travel speed: 25.1 km/h
# Edge from 2834814897 to 53119168 has travel speed: 25.1 km/h
# Edge from 2834816916 to 53115407 has travel speed: 25.1 km/h
# Edge from 2890584258 to 256338808 has travel speed: 24.1 km/h
# Edge from 2890584258 to 53035699 has travel speed: 24.1 km/h
# Edge from 2890584258 to 245523440 has travel speed: 36.5 km/h
# Edge from 3905291938 to 53099375 has travel speed: 24.1 km/h
# Edge from 4606504193 to 8573260363 has travel speed: 25.1 km/h
# Edge from 4606504193 to 53088882 has travel speed: 25.1 km/h
# Edge from 4606504193 to 53079888 has travel speed: 25.1 km/h
# Edge from 4671607162 to 53114726 has travel speed: 44.3 km/h
# Edge from 4671607162 to 53085009 has travel speed: 25.1 km/h
# Edge from 4671607162 to 53064330 has travel speed: 44.3 km/h
# Edge from 8573260363 to 4606504193 has travel speed: 25.1 km/h
# Edge from 9124733144 to 53041668 has travel speed: 25.1 km/h
# Edge from 9124733144 to 53076250 has travel speed: 25.1 km/h
# Edge from 9124766429 to 53076244 has travel speed: 25.1 km/h
# Edge from 9124766429 to 53075606 has travel speed: 44.3 km/h
# Edge from 9124766429 to 53076245 has travel speed: 25.1 km/h
# Edge from 9231102999 to 2391023380 has travel speed: 25.1 km/h
# Edge from 9231102999 to 53152083 has travel speed: 25.1 km/h
# Edge from 9656853491 to 9656853494 has travel speed: 25.1 km/h
# Edge from 9656853491 to 53044661 has travel speed: 24.1 km/h
# Edge from 9656853491 to 53059885 has travel speed: 24.1 km/h
# Edge from 9656853494 to 9656853491 has travel speed: 25.1 km/h
# Edge from 9656853494 to 53044661 has travel speed: 25.1 km/h
# Edge from 9656853494 to 53044664 has travel speed: 25.1 km/h
# Edge from 10232094660 to 53145205 has travel speed: 25.1 km/h
# Edge from 10232094660 to 683790735 has travel speed: 36.5 km/h
# Edge from 10677487586 to 53149343 has travel speed: 25.1 km/h
# Edge from 10677487586 to 260707482 has travel speed: 25.1 km/h
# Edge from 10684132265 to 53085387 has travel speed: 40.2 km/h
# Edge from 10684132265 to 53093362 has travel speed: 25.1 km/h
# Edge from 10684132265 to 53078467 has travel speed: 40.2 km/h
# Edge from 10747500178 to 53057697 has travel speed: 25.1 km/h
# Edge from 10747500178 to 53062958 has travel speed: 25.1 km/h
# Edge from 10747500178 to 53062956 has travel speed: 25.1 km/h
# Edge from 10879933448 to 53036558 has travel speed: 40.2 km/h
# Edge from 10879933448 to 682931951 has travel speed: 40.2 km/h
# Edge from 10879933448 to 53028192 has travel speed: 25.1 km/h
# Edge from 11036463561 to 53119042 has travel speed: 24.1 km/h
